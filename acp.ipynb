# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# Import des données
df = pd.read_csv('datas/olist_products_dataset.csv')
# Standardisation des données
# Il est crucial de standardiser les données avant d'appliquer l'ACP, surtout si les unités de mesure des variables diffèrent.
X = StandardScaler().fit_transform(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_72690/649154714.py in <module>
#       7 # Standardisation des données
#       8 # Il est crucial de standardiser les données avant d'appliquer l'ACP, surtout si les unités de mesure des variables diffèrent.
# ----> 9 X = StandardScaler().fit_transform(df)
#
# ~/.local/lib/python3.10/site-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     155     @wraps(f)
#     156     def wrapped(self, X, *args, **kwargs):
# --> 157         data_to_wrap = f(self, X, *args, **kwargs)
#     158         if isinstance(data_to_wrap, tuple):
#     159             # only wrap the first output for cross decomposition
#
# ~/.local/lib/python3.10/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     914         if y is None:
# ...
